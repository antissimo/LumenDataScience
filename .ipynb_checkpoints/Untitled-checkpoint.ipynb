# %% [markdown]
# # LUMEN NATJECANJE

# %%
## Read data and stoore it in DataFframe titled original_data

# %%
import  pandas as pd

dataset_path = './data/lumen/export_df.parquet'
original_data=pd.read_parquet(dataset_path)

#return first 10 rows to see what the data looks like
original_data.head(10)
# Out:
#    hotel_id datum_dolaska datum_kreiranja_rezervacije datum_odjave  \
# 0         0    2015-07-01                  2015-01-21   2015-07-01
# 1         0    2015-07-01                  2015-06-10   2015-07-01
# 2         0    2015-07-01                  2015-05-13   2015-07-02
# 3         0    2015-07-01                  2014-05-30   2015-07-02
# 4         0    2015-07-01                  2014-07-06   2015-07-03
# 5         0    2015-07-01                  2015-04-21   2015-07-03
# 6         0    2015-07-01                  2015-06-25   2015-07-03
# 7         0    2015-07-01                  2014-09-15   2015-07-03
# 8         0    2015-07-01                  2015-06-30   2015-07-04
# 9         0    2015-07-01                  2015-06-28   2015-07-04
#
#   datum_otkazivanja_rezervacije  broj_odraslih_gostiju  broj_djece_gostiju  \
# 0                          None                      2                 0.0
# 1                          None                      2                 0.0
# ...

# %%
#print the size of the data
original_data.shape
# Out:
# (119210, 14)

# %%
#print out the values of columns 
original_data.columns
# Out:
# Index(['hotel_id', 'datum_dolaska', 'datum_kreiranja_rezervacije',
#        'datum_odjave', 'datum_otkazivanja_rezervacije',
#        'broj_odraslih_gostiju', 'broj_djece_gostiju', 'zemlja_gosta',
#        'kanal_prodaje_id', 'tip_sobe_id', 'cijena_nocenja',
#        'status_rezervacije', 'rezervacija_id', 'gost_id'],
#       dtype='object')

# %%
#get the number of missing data points per column
missing_values_count=original_data.isnull().sum()
print(missing_values_count)
# Out:
# hotel_id                             0
# datum_dolaska                        0
# datum_kreiranja_rezervacije          0
# datum_odjave                         0
# datum_otkazivanja_rezervacije    75011
# broj_odraslih_gostiju                0
# broj_djece_gostiju                   0
# zemlja_gosta                         0
# kanal_prodaje_id                     0
# tip_sobe_id                          0
# cijena_nocenja                       0
# status_rezervacije                   0
# rezervacija_id                       0
# gost_id                              0
# dtype: int64

# %%
#check if there are duuplicate rows

duplicate_rows=original_data[original_data.duplicated()]
print(duplicate__rows)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[14], line 4
#       1 #check if there are duuplicate rows
#       2 #print the size of the data
#       3 duplicate_rows=original_data[original_data.duplicated()]
# ----> 4 print(duplicate__rows)
#
# NameError: name 'duplicate__rows' is not defined
